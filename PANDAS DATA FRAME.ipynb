# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Different Methods of Creating Data Frame

# %%
# we creat data frame by usnig list

lis = [
    [10,20,'A'],
    [40,50,'B'],
    
]

df = pd.DataFrame(lis,columns =['marks','age','grade'])

df
# Out:
#    marks  age grade
# 0     10   20     A
# 1     40   50     B

# %%
# we create dataframe by using dictionary of list

dic = {
    'Name':['Ikram','Ehsan','Ibrahim','Mati'],
    'Age':[36,38,14,16],
    'Qual' :[16,14,12,10]
    
}

df1 = pd.DataFrame(dic)
df1
# Out:
#       Name  Age  Qual
# 0    Ikram   36    16
# 1    Ehsan   38    14
# 2  Ibrahim   14    12
# 3     Mati   16    10

# %%
# we create dataframe by using list  of dictionary 

lis_dic = [
    
    {'Name':'Hadi','Age':20,'Gender':'Male'},
    {'Name':'Anabia','Age':15,'Gender':'Female'}
]

df2 = pd.DataFrame(lis_dic)

df2
# Out:
#      Name  Age  Gender
# 0    Hadi   20    Male
# 1  Anabia   15  Female

# %%
pd.DataFrame([
    (10,20,30),
    (90,70,50),
    (12,45,65)
    ])
# Out:
#     0   1   2
# 0  10  20  30
# 1  90  70  50
# 2  12  45  65

# %%
df_tuple = pd.DataFrame({
    'iq':(10,20,30),
    'percentage':(90,70,50),
    'age':(12,45,65)
})

df_tuple
# Out:
#    iq  percentage  age
# 0  10          90   12
# 1  20          70   45
# 2  30          50   65

# %%
# index it gives the indexes of a dataframe

df1.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
# reading data frame

ipl = pd.read_csv('E:\Datasets\Pandas_dataSets\ipl-matches.csv')

ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
movies = pd.read_csv('E:\Datasets\Pandas_dataSets\movies.csv')

movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
# index give the range of indexes in a dataframe

print(ipl.index)

print(movies.index)
# Out:
# RangeIndex(start=0, stop=950, step=1)
# RangeIndex(start=0, stop=1629, step=1)

# %%
# columns give the list of all columns in a dataframe

print(ipl.columns)

print(movies.columns)
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')
# Index(['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y',
#        'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres',
#        'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date'],
#       dtype='object')

# %%
# dtypes give the list of datatypes of all columns in a dataframe

ipl.dtypes
# Out:
# ID                   int64
# City                object
# Date                object
# Season              object
# MatchNumber         object
# Team1               object
# Team2               object
# Venue               object
# TossWinner          object
# TossDecision        object
# SuperOver           object
# WinningTeam         object
# WonBy               object
# Margin             float64
# method              object
# Player_of_Match     object
# Team1Players        object
# Team2Players        object
# Umpire1             object
# Umpire2             object
# dtype: object

# %%
movies.dtypes
# Out:
# title_x              object
# imdb_id              object
# poster_path          object
# wiki_link            object
# title_y              object
# original_title       object
# is_adult              int64
# year_of_release       int64
# runtime              object
# genres               object
# imdb_rating         float64
# imdb_votes            int64
# story                object
# summary              object
# tagline              object
# actors               object
# wins_nominations     object
# release_date         object
# dtype: object

# %%
# info give the information of all columns in a dataframe

ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
# ...

# %%
# select_dtypes give a new data frame with specific data type

ipl.select_dtypes(include=['float64','int64'])
# Out:
#           ID  Margin
# 0    1312200     7.0
# 1    1312199     7.0
# 2    1312198    14.0
# 3    1312197     7.0
# 4    1304116     5.0
# ..       ...     ...
# 945   335986     5.0
# 946   335985     5.0
# 947   335984     9.0
# 948   335983    33.0
# 949   335982   140.0
#
# [950 rows x 2 columns]

# %%
movies.select_dtypes(['int','float'])
# Out:
#       is_adult  year_of_release  imdb_rating  imdb_votes
# 0            0             2019          8.4       35112
# 1            0             2019          4.1          73
# 2            0             2019          6.1        5549
# 3            0             2019          6.0        1891
# 4            0             2018          7.3         280
# ...        ...              ...          ...         ...
# 1624         0             2001          4.9         278
# 1625         0             2001          3.0         133
# 1626         0             2018          6.1          13
# 1627         0             2019          7.4          38
# 1628         0             2011          9.0        2968
#
# [1629 rows x 4 columns]

# %%
# values function give us a numpy array of data frame values
df1.values
# Out:
# array([['Ikram', 36, 16],
#        ['Ehsan', 38, 14],
#        ['Ibrahim', 14, 12],
#        ['Mati', 16, 10]], dtype=object)

# %%
ipl.values
# Out:
# array([[1312200, 'Ahmedabad', '2022-05-29', ...,
#         "['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pandya', 'DA Miller', 'R Tewatia', 'Rashid Khan', 'R Sai Kishore', 'LH Ferguson', 'Yash Dayal', 'Mohammed Shami']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312199, 'Ahmedabad', '2022-05-27', ...,
#         "['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D Padikkal', 'SO Hetmyer', 'R Parag', 'R Ashwin', 'TA Boult', 'YS Chahal', 'M Prasidh Krishna', 'OC McCoy']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312198, 'Kolkata', '2022-05-25', ...,
#         "['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda', 'MP Stoinis', 'E Lewis', 'KH Pandya', 'PVD Chameera', 'Mohsin Khan', 'Avesh Khan', 'Ravi Bishnoi']",
#         'J Madanagopal', 'MA Gough'],
#        ...,
#        [335984, 'Delhi', '2008-04-19', ...,
#         "['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif', 'DS Lehmann', 'RA Jadeja', 'M Rawat', 'D Salunkhe', 'SK Warne', 'SK Trivedi', 'MM Patel']",
# ...

# %%
ipl.axes
# Out:
# [RangeIndex(start=0, stop=950, step=1),
#  Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#         'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#         'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#         'Team2Players', 'Umpire1', 'Umpire2'],
#        dtype='object')]

# %%
# ndim give the dimensions of data it provide 1 in case od series and give 2 in case of data frame

ipl.ndim
movies.ndim
# Out:
# 2

# %%
# size count the all number of values in data frame including NaN values

print(ipl.size)
print(movies.size)
# Out:
# 19000
# 29322

# %%
# count function count all the number of values in each column without NaN values
ipl.count()
# Out:
# ID                 950
# City               899
# Date               950
# Season             950
# MatchNumber        950
# Team1              950
# Team2              950
# Venue              950
# TossWinner         950
# TossDecision       950
# SuperOver          946
# WinningTeam        946
# WonBy              950
# Margin             932
# method              19
# Player_of_Match    946
# Team1Players       950
# Team2Players       950
# Umpire1            950
# Umpire2            950
# dtype: int64

# %%
# shape give the total number of rows and columns

ipl.shape
# Out:
# (950, 20)

# %%
ipl.memory_usage()
# Out:
# Index               128
# ID                 7600
# City               7600
# Date               7600
# Season             7600
# MatchNumber        7600
# Team1              7600
# Team2              7600
# Venue              7600
# TossWinner         7600
# TossDecision       7600
# SuperOver          7600
# WinningTeam        7600
# WonBy              7600
# Margin             7600
# method             7600
# Player_of_Match    7600
# Team1Players       7600
# Team2Players       7600
# Umpire1            7600
# Umpire2            7600
# dtype: int64

# %%
movies.memory_usage()
# Out:
# Index                 128
# title_x             13032
# imdb_id             13032
# poster_path         13032
# wiki_link           13032
# title_y             13032
# original_title      13032
# is_adult            13032
# year_of_release     13032
# runtime             13032
# genres              13032
# imdb_rating         13032
# imdb_votes          13032
# story               13032
# summary             13032
# tagline             13032
# actors              13032
# wins_nominations    13032
# release_date        13032
# dtype: int64

# %%
df1.astype({'Age':'float'})
# Out:
#       Name   Age  Qual
# 0    Ikram  36.0    16
# 1    Ehsan  38.0    14
# 2  Ibrahim  14.0    12
# 3     Mati  16.0    10

# %%
df1.dtypes
# Out:
# Name    object
# Age      int64
# Qual     int64
# dtype: object

# %%
# this function can also be use to change the data type

df1.convert_dtypes(infer_objects='Age',convert_integer=int)
# Out:
#       Name  Age  Qual
# 0    Ikram   36    16
# 1    Ehsan   38    14
# 2  Ibrahim   14    12
# 3     Mati   16    10

# %%
# copy function provide the copy of data frame
new_df = df1.copy()

new_df
# Out:
#       Name  Age  Qual
# 0    Ikram   36    16
# 1    Ehsan   38    14
# 2  Ibrahim   14    12
# 3     Mati   16    10

# %%
df3 = new_df.to_numpy()

df3
# Out:
# array([['Ikram', 36, 16],
#        ['Ehsan', 38, 14],
#        ['Ibrahim', 14, 12],
#        ['Mati', 16, 10]], dtype=object)

# %%
new_df.to_csv(path_or_buf='E:\\Datasets\\Pandas_dataSets\\abc.csv')

# %%
# head function gives us a top 5 rows of a dataframe

ipl.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
movies.head()
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
# head function gives us a last 5 rows of a dataframe

ipl.tail()
# Out:
#          ID        City        Date   Season MatchNumber  \
# 945  335986     Kolkata  2008-04-20  2007/08           4
# 946  335985      Mumbai  2008-04-20  2007/08           5
# 947  335984       Delhi  2008-04-19  2007/08           3
# 948  335983  Chandigarh  2008-04-19  2007/08           2
# 949  335982   Bangalore  2008-04-18  2007/08           1
#
#                            Team1                        Team2  \
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 945                                Eden Gardens              Deccan Chargers
# 946                            Wankhede Stadium               Mumbai Indians
# ...

# %%
# sample function gives us a randomly rows of a dataframe
ipl.sample()
# Out:
#          ID       City        Date Season MatchNumber  \
# 697  548310  Bangalore  2012-04-07   2012           5
#
#                            Team1             Team2                  Venue  \
# 697  Royal Challengers Bangalore  Delhi Daredevils  M Chinnaswamy Stadium
#
#            TossWinner TossDecision SuperOver                  WinningTeam  \
# 697  Delhi Daredevils        field         N  Royal Challengers Bangalore
#
#     WonBy  Margin method Player_of_Match  \
# 697  Runs    20.0    NaN  AB de Villiers
#
#                                           Team1Players  \
# 697  ['AB McDonald', 'CA Pujara', 'V Kohli', 'AB de...
#
#                                           Team2Players   Umpire1 Umpire2
# 697  ['AJ Finch', 'V Sehwag', 'NV Ojha', 'Y Venugop...  S Asnani  S Ravi

# %%
# it randomly select the 5 rows

movies.sample(5)
# Out:
#               title_x    imdb_id  \
# 36        Kabir Singh  tt8983202
# 1375     Paisa Vasool  tt0396782
# 681   Dangerous Ishhq  tt1971365
# 210     Munna Michael  tt6117702
# 49    The Sky Is Pink  tt8902990
#
#                                             poster_path  \
# 36    https://upload.wikimedia.org/wikipedia/en/thum...
# 1375  https://upload.wikimedia.org/wikipedia/en/thum...
# 681   https://upload.wikimedia.org/wikipedia/en/thum...
# 210   https://upload.wikimedia.org/wikipedia/en/thum...
# 49    https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                           wiki_link          title_y  \
# 36        https://en.wikipedia.org/wiki/Kabir_Singh      Kabir Singh
# 1375     https://en.wikipedia.org/wiki/Paisa_Vasool     Paisa Vasool
# 681    https://en.wikipedia.org/wiki/Dangerous_Ishq   Dangerous Ishq
# 210     https://en.wikipedia.org/wiki/Munna_Michael    Munna Michael
# 49    https://en.wikipedia.org/wiki/The_Sky_Is_Pink  The Sky Is Pink
#
# ...

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
# describe function gives the statistical information of numerical columns

ipl.describe()
# Out:
#                  ID      Margin
# count  9.500000e+02  932.000000
# mean   8.304852e+05   17.056867
# std    3.375678e+05   21.633109
# min    3.359820e+05    1.000000
# 25%    5.012612e+05    6.000000
# 50%    8.297380e+05    8.000000
# 75%    1.175372e+06   19.000000
# max    1.312200e+06  146.000000

# %%
movies.describe()
# Out:
#        is_adult  year_of_release  imdb_rating     imdb_votes
# count    1629.0      1629.000000  1629.000000    1629.000000
# mean        0.0      2010.263966     5.557459    5384.263352
# std         0.0         5.381542     1.567609   14552.103231
# min         0.0      2001.000000     0.000000       0.000000
# 25%         0.0      2005.000000     4.400000     233.000000
# 50%         0.0      2011.000000     5.600000    1000.000000
# 75%         0.0      2015.000000     6.800000    4287.000000
# max         0.0      2019.000000     9.400000  310481.000000

# %% [markdown]
# ## Data Selection and Filtering

# %%
# df[]
# df.loc[]
# df.iloc[]
# df.at[]
# df.iat[]
# df.query()
# df.filter()

# %%
# selecting columns from a dataframe

# select a single column from data frame

ipl['City']

type(ipl['City'])
# Out:
# pandas.core.series.Series

# %%
# selecting multiple columns fro a dat frame

ipl[['Team1','Team2','WinningTeam']]
# Out:
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 4            Sunrisers Hyderabad                 Punjab Kings
# ..                           ...                          ...
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                      WinningTeam
# 0                 Gujarat Titans
# 1               Rajasthan Royals
# 2    Royal Challengers Bangalore
# 3                 Gujarat Titans
# 4                   Punjab Kings
# ...

# %%
# Selcting rows
for i in df1.items():
    print(i)
# Out:
# ('Name', 0      Ikram
# 1      Ehsan
# 2    Ibrahim
# 3       Mati
# Name: Name, dtype: object)
# ('Age', 0    36
# 1    38
# 2    14
# 3    16
# Name: Age, dtype: int64)
# ('Qual', 0    16
# 1    14
# 2    12
# 3    10
# Name: Qual, dtype: int64)

# %%
df1.keys()
# Out:
# Index(['Name', 'Age', 'Qual'], dtype='object')

# %%
ipl.keys()
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
movies.iloc[4]
# Out:
# title_x                                               Evening Shadows
# imdb_id                                                     tt6028796
# poster_path                                                       NaN
# wiki_link               https://en.wikipedia.org/wiki/Evening_Shadows
# title_y                                               Evening Shadows
# original_title                                        Evening Shadows
# is_adult                                                            0
# year_of_release                                                  2018
# runtime                                                           102
# genres                                                          Drama
# imdb_rating                                                       7.3
# imdb_votes                                                        280
# story               While gay rights and marriage equality has bee...
# ...

# %%
ipl.iloc[2:5]
# Out:
#         ID     City        Date Season  MatchNumber  \
# 2  1312198  Kolkata  2022-05-25   2022   Eliminator
# 3  1312197  Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116   Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                       Venue            TossWinner TossDecision SuperOver  \
# 2     Eden Gardens, Kolkata  Lucknow Super Giants        field         N
# 3     Eden Gardens, Kolkata        Gujarat Titans        field         N
# 4  Wankhede Stadium, Mumbai   Sunrisers Hyderabad          bat         N
#
#                    WinningTeam    WonBy  Margin method Player_of_Match  \
# 2  Royal Challengers Bangalore     Runs    14.0    NaN      RM Patidar
# 3               Gujarat Titans  Wickets     7.0    NaN       DA Miller
# ...

# %%
ipl[10:100]
# Out:
#          ID         City        Date Season MatchNumber  \
# 10  1304110  Navi Mumbai  2022-05-16   2022          64
# 11  1304109       Mumbai  2022-05-15   2022          63
# 12  1304108       Mumbai  2022-05-15   2022          62
# 13  1304107         Pune  2022-05-14   2022          61
# 14  1304106       Mumbai  2022-05-13   2022          60
# ..      ...          ...         ...    ...         ...
# 95  1254098    Abu Dhabi  2021-09-26   2021          38
# 96  1254108        Dubai  2021-09-26   2021          39
# 97  1254097    Abu Dhabi  2021-09-25   2021          36
# 98  1254107      Sharjah  2021-09-25   2021          37
# 99  1254113      Sharjah  2021-09-24   2021          35
#
#                           Team1                        Team2  \
# 10               Delhi Capitals                 Punjab Kings
# 11             Rajasthan Royals         Lucknow Super Giants
# 12          Chennai Super Kings               Gujarat Titans
# ...

# %%
movies[100:500:4]
# Out:
#                      title_x    imdb_id  \
# 100      October (2018 film)  tt7700730
# 104                 Daas Dev  tt4979110
# 108         High Jack (film)  tt8175968
# 112  Bhavesh Joshi Superhero  tt6129302
# 116                    Sanju  tt6452574
# ..                       ...        ...
# 480            W (2014 film)  tt3166542
# 484               Jal (film)  tt2708550
# 488      Station (2014 film)  tt2191164
# 492     Kya Dilli Kya Lahore  tt2063745
# 496                  Mastram  tt3431714
#
#                                            poster_path  \
# 100  https://upload.wikimedia.org/wikipedia/en/thum...
# 104  https://upload.wikimedia.org/wikipedia/en/thum...
# 108  https://upload.wikimedia.org/wikipedia/en/thum...
# 112  https://upload.wikimedia.org/wikipedia/en/thum...
# 116  https://upload.wikimedia.org/wikipedia/en/thum...
# ..                                                 ...
# 480  https://upload.wikimedia.org/wikipedia/en/e/e0...
# ...

# %%
ipl[::10]
# Out:
#           ID         City        Date   Season MatchNumber  \
# 0    1312200    Ahmedabad  2022-05-29     2022       Final
# 10   1304110  Navi Mumbai  2022-05-16     2022          64
# 20   1304100       Mumbai  2022-05-08     2022          54
# 30   1304090  Navi Mumbai  2022-04-30     2022          44
# 40   1304080       Mumbai  2022-04-22     2022          34
# ..       ...          ...         ...      ...         ...
# 900   336002    Hyderabad  2008-05-25  2007/08          51
# 910   336022        Delhi  2008-05-17  2007/08          40
# 920   336011       Jaipur  2008-05-09  2007/08          30
# 930   336001      Chennai  2008-05-02  2007/08          20
# 940   335991   Chandigarh  2008-04-25  2007/08          10
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 10                Delhi Capitals                 Punjab Kings
# 20   Royal Challengers Bangalore          Sunrisers Hyderabad
# ...

# %%
ipl[0:10]
# Out:
#         ID         City        Date Season  MatchNumber  \
# 0  1312200    Ahmedabad  2022-05-29   2022        Final
# 1  1312199    Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198      Kolkata  2022-05-25   2022   Eliminator
# 3  1312197      Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116       Mumbai  2022-05-22   2022           70
# 5  1304115       Mumbai  2022-05-21   2022           69
# 6  1304114       Mumbai  2022-05-20   2022           68
# 7  1304113       Mumbai  2022-05-19   2022           67
# 8  1304112  Navi Mumbai  2022-05-18   2022           66
# 9  1304111       Mumbai  2022-05-17   2022           65
#
#                          Team1                        Team2  \
# 0             Rajasthan Royals               Gujarat Titans
# 1  Royal Challengers Bangalore             Rajasthan Royals
# 2  Royal Challengers Bangalore         Lucknow Super Giants
# 3             Rajasthan Royals               Gujarat Titans
# ...

# %%
ipl.iloc[0:10]
# Out:
#         ID         City        Date Season  MatchNumber  \
# 0  1312200    Ahmedabad  2022-05-29   2022        Final
# 1  1312199    Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198      Kolkata  2022-05-25   2022   Eliminator
# 3  1312197      Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116       Mumbai  2022-05-22   2022           70
# 5  1304115       Mumbai  2022-05-21   2022           69
# 6  1304114       Mumbai  2022-05-20   2022           68
# 7  1304113       Mumbai  2022-05-19   2022           67
# 8  1304112  Navi Mumbai  2022-05-18   2022           66
# 9  1304111       Mumbai  2022-05-17   2022           65
#
#                          Team1                        Team2  \
# 0             Rajasthan Royals               Gujarat Titans
# 1  Royal Challengers Bangalore             Rajasthan Royals
# 2  Royal Challengers Bangalore         Lucknow Super Giants
# 3             Rajasthan Royals               Gujarat Titans
# ...

# %%
# use iloc function this function use to access the all rows using index

ipl.iloc[5]
# Out:
# ID                                                           1304115
# City                                                          Mumbai
# Date                                                      2022-05-21
# Season                                                          2022
# MatchNumber                                                       69
# Team1                                                 Delhi Capitals
# Team2                                                 Mumbai Indians
# Venue                                       Wankhede Stadium, Mumbai
# TossWinner                                            Mumbai Indians
# TossDecision                                                   field
# SuperOver                                                          N
# WinningTeam                                           Mumbai Indians
# WonBy                                                        Wickets
# Margin                                                           5.0
# ...

# %%
ipl.iloc[5:20]
# Out:
#          ID         City        Date Season MatchNumber  \
# 5   1304115       Mumbai  2022-05-21   2022          69
# 6   1304114       Mumbai  2022-05-20   2022          68
# 7   1304113       Mumbai  2022-05-19   2022          67
# 8   1304112  Navi Mumbai  2022-05-18   2022          66
# 9   1304111       Mumbai  2022-05-17   2022          65
# 10  1304110  Navi Mumbai  2022-05-16   2022          64
# 11  1304109       Mumbai  2022-05-15   2022          63
# 12  1304108       Mumbai  2022-05-15   2022          62
# 13  1304107         Pune  2022-05-14   2022          61
# 14  1304106       Mumbai  2022-05-13   2022          60
# 15  1304105       Mumbai  2022-05-12   2022          59
# 16  1304104  Navi Mumbai  2022-05-11   2022          58
# 17  1304103         Pune  2022-05-10   2022          57
# 18  1304102  Navi Mumbai  2022-05-09   2022          56
# 19  1304101  Navi Mumbai  2022-05-08   2022          55
#
#                     Team1                        Team2  \
# ...

# %%
ipl.iloc[10:100:4]
# Out:
#          ID         City        Date Season MatchNumber  \
# 10  1304110  Navi Mumbai  2022-05-16   2022          64
# 14  1304106       Mumbai  2022-05-13   2022          60
# 18  1304102  Navi Mumbai  2022-05-09   2022          56
# 22  1304098       Mumbai  2022-05-07   2022          52
# 26  1304094  Navi Mumbai  2022-05-03   2022          48
# 30  1304090  Navi Mumbai  2022-04-30   2022          44
# 34  1304086       Mumbai  2022-04-27   2022          40
# 38  1304082       Mumbai  2022-04-23   2022          36
# 42  1304078       Mumbai  2022-04-20   2022          32
# 46  1304074       Mumbai  2022-04-17   2022          28
# 50  1304070       Mumbai  2022-04-14   2022          24
# 54  1304066       Mumbai  2022-04-10   2022          20
# 58  1304062       Mumbai  2022-04-08   2022          16
# 62  1304058       Mumbai  2022-04-04   2022          12
# 66  1304054       Mumbai  2022-04-01   2022           8
# 70  1304050       Mumbai  2022-03-28   2022           4
# ...

# %%
ipl.iloc[:20]
# Out:
#          ID         City        Date Season  MatchNumber  \
# 0   1312200    Ahmedabad  2022-05-29   2022        Final
# 1   1312199    Ahmedabad  2022-05-27   2022  Qualifier 2
# 2   1312198      Kolkata  2022-05-25   2022   Eliminator
# 3   1312197      Kolkata  2022-05-24   2022  Qualifier 1
# 4   1304116       Mumbai  2022-05-22   2022           70
# 5   1304115       Mumbai  2022-05-21   2022           69
# 6   1304114       Mumbai  2022-05-20   2022           68
# 7   1304113       Mumbai  2022-05-19   2022           67
# 8   1304112  Navi Mumbai  2022-05-18   2022           66
# 9   1304111       Mumbai  2022-05-17   2022           65
# 10  1304110  Navi Mumbai  2022-05-16   2022           64
# 11  1304109       Mumbai  2022-05-15   2022           63
# 12  1304108       Mumbai  2022-05-15   2022           62
# 13  1304107         Pune  2022-05-14   2022           61
# 14  1304106       Mumbai  2022-05-13   2022           60
# ...

# %%
# loc function use to access the rows by using label

crypto = pd.read_csv('E:\Datasets\Crypto.csv')
crypto
# Out:
#                      name     abbr  \
# 0                 Bitcoin      BTC
# 1                Ethereum      ETH
# 2                  Tether     USDT
# 3                     BNB      BNB
# 4                  Solana      SOL
# ...                   ...      ...
# 21342                  ぺぺ       ぺぺ
# 21343               喵喵喵喵喵    喵喵喵喵喵
# 21344  四皇 - Four Emperors    YONKŌ
# 21345             忠 LOYAL  LOYAL 忠
# 21346               无条件为你    无条件为你
#
#                                          crypturl         price  volume24hrs  \
# 0                https://crypto.com/price/bitcoin  6.273267e+04  272076.9766
# 1               https://crypto.com/price/ethereum  3.027220e+03  981408.7883
# 2                 https://crypto.com/price/tether  9.999000e-01  944792.0394
# 3                    https://crypto.com/price/bnb  5.938500e+02  556334.5330
# 4                 https://crypto.com/price/solana  1.525900e+02  866929.0575
# ...

# %%
crypto.set_index('name',inplace=True)
crypto
# Out:
#                        abbr                                    crypturl  \
# name
# Bitcoin                 BTC            https://crypto.com/price/bitcoin
# Ethereum                ETH           https://crypto.com/price/ethereum
# Tether                 USDT             https://crypto.com/price/tether
# BNB                     BNB                https://crypto.com/price/bnb
# Solana                  SOL             https://crypto.com/price/solana
# ...                     ...                                         ...
# ぺぺ                       ぺぺ           https://crypto.com/price/pepe-eth
# 喵喵喵喵喵                 喵喵喵喵喵  https://crypto.com/price/miaomiaomiaoerc20
# 四皇 - Four Emperors    YONKŌ      https://crypto.com/price/four-emperors
# 忠 LOYAL             LOYAL 忠              https://crypto.com/price/loyal
# 无条件为你                 无条件为你              https://crypto.com/price/wtjwn
#
#                            price  volume24hrs    marketcap  circulatingsupply  \
# name
# ...

# %%
crypto.loc['BNB':'ApeCoin']
# Out:
#                    abbr                                 crypturl      price  \
# name
# BNB                 BNB             https://crypto.com/price/bnb  593.85000
# Solana              SOL          https://crypto.com/price/solana  152.59000
# USD Coin           USDC        https://crypto.com/price/usd-coin    1.00000
# XRP                 XRP             https://crypto.com/price/xrp    0.51730
# Toncoin         TONCOIN         https://crypto.com/price/toncoin    6.64000
# ...                 ...                                      ...        ...
# Ordinals           ORDI        https://crypto.com/price/ordinals   39.00000
# Gnosis              GNO      https://crypto.com/price/gnosis-gno  304.06000
# Helium              HNT          https://crypto.com/price/helium    4.86000
# Nervos Network      CKB  https://crypto.com/price/nervos-network    0.01766
# ApeCoin             APE     https://crypto.com/price/apecoin-ape    1.28000
#
# ...

# %%
crypto
# Out:
#                      name     abbr  \
# 0                 Bitcoin      BTC
# 1                Ethereum      ETH
# 2                  Tether     USDT
# 3                     BNB      BNB
# 4                  Solana      SOL
# ...                   ...      ...
# 21342                  ぺぺ       ぺぺ
# 21343               喵喵喵喵喵    喵喵喵喵喵
# 21344  四皇 - Four Emperors    YONKŌ
# 21345             忠 LOYAL  LOYAL 忠
# 21346               无条件为你    无条件为你
#
#                                          crypturl         price  volume24hrs  \
# 0                https://crypto.com/price/bitcoin  6.273267e+04  272076.9766
# 1               https://crypto.com/price/ethereum  3.027220e+03  981408.7883
# 2                 https://crypto.com/price/tether  9.999000e-01  944792.0394
# 3                    https://crypto.com/price/bnb  5.938500e+02  556334.5330
# 4                 https://crypto.com/price/solana  1.525900e+02  866929.0575
# ...

# %%
df1
# Out:
#          Age  Qual
# Name
# Ikram     36    16
# Ehsan     38    14
# Ibrahim   14    12
# Mati      16    10

# %%
df1.loc['Ikram']
# Out:
# Age     36
# Qual    16
# Name: Ikram, dtype: int64

# %%
df1.loc['Ikram':'Ibrahim']
# Out:
#          Age  Qual
# Name
# Ikram     36    16
# Ehsan     38    14
# Ibrahim   14    12

# %%
df1.iloc[2:4]
# Out:
#          Age  Qual
# Name
# Ibrahim   14    12
# Mati      16    10

# %%
crypto.loc['Tether':'Pyth Network':3]
# Out:
#                      abbr                                          crypturl  \
# name
# Tether               USDT                   https://crypto.com/price/tether
# USD Coin             USDC                 https://crypto.com/price/usd-coin
# Dogecoin             DOGE                 https://crypto.com/price/dogecoin
# Avalanche            AVAX                https://crypto.com/price/avalanche
# Polkadot              DOT             https://crypto.com/price/polkadot-new
# NEAR Protocol        NEAR            https://crypto.com/price/near-protocol
# Internet Computer     ICP        https://crypto.com/price/internet-computer
# Uniswap               UNI                  https://crypto.com/price/uniswap
# Hedera               HBAR                   https://crypto.com/price/hedera
# Pepe                 PEPE                     https://crypto.com/price/pepe
# Cronos                CRO                   https://crypto.com/price/cronos
# ...

# %%
# if we want to access specific rows
# we use fancy indexing

crpto.iloc[[10,20,50]]
# Out:
#                  name  abbr                                    crypturl  \
# 10          Shiba Inu  SHIB          https://crypto.com/price/shiba-inu
# 20  Internet Computer   ICP  https://crypto.com/price/internet-computer
# 50             Fantom   FTM             https://crypto.com/price/fantom
#
#         price   volume24hrs    marketcap  circulatingsupply    maxsupply  \
# 10   0.000023   86260.83219  3,74,571.88        1897253.157  367209180.6
# 20  12.320000  143342.09970  8,98,738.14        2532902.473  917304879.6
# 50   0.718500  629290.92330  1,51,898.38        3055085.999  844304864.1
#
#     totalsupply  date_taken  Unnamed: 10  Unnamed: 11
# 10  887502481.4  22-02-2005          NaN          NaN
# 20  889054578.6  19-12-2015          NaN          NaN
# 50  961542399.2  13-08-2023          NaN          NaN

# %%
# if we want to accsee the specific rows and columns
ipl.iloc[10:20,2:7]
# Out:
#           Date Season MatchNumber                  Team1  \
# 10  2022-05-16   2022          64         Delhi Capitals
# 11  2022-05-15   2022          63       Rajasthan Royals
# 12  2022-05-15   2022          62    Chennai Super Kings
# 13  2022-05-14   2022          61  Kolkata Knight Riders
# 14  2022-05-13   2022          60           Punjab Kings
# 15  2022-05-12   2022          59    Chennai Super Kings
# 16  2022-05-11   2022          58       Rajasthan Royals
# 17  2022-05-10   2022          57         Gujarat Titans
# 18  2022-05-09   2022          56  Kolkata Knight Riders
# 19  2022-05-08   2022          55    Chennai Super Kings
#
#                           Team2
# 10                 Punjab Kings
# 11         Lucknow Super Giants
# 12               Gujarat Titans
# 13          Sunrisers Hyderabad
# 14  Royal Challengers Bangalore
# 15               Mumbai Indians
# 16               Delhi Capitals
# 17         Lucknow Super Giants
# 18               Mumbai Indians
# ...

# %%
crypto.loc['Shiba Inu':'Uniswap','abbr':'maxsupply']
# Out:
#                     abbr                                       crypturl  \
# name
# Shiba Inu           SHIB             https://crypto.com/price/shiba-inu
# Avalanche           AVAX             https://crypto.com/price/avalanche
# TRON                 TRX                  https://crypto.com/price/tron
# Wrapped Bitcoin     WBTC       https://crypto.com/price/wrapped-bitcoin
# Polkadot             DOT          https://crypto.com/price/polkadot-new
# Bitcoin Cash         BCH          https://crypto.com/price/bitcoin-cash
# Chainlink           LINK             https://crypto.com/price/chainlink
# NEAR Protocol       NEAR         https://crypto.com/price/near-protocol
# Polygon            MATIC               https://crypto.com/price/polygon
# Litecoin             LTC              https://crypto.com/price/litecoin
# Internet Computer    ICP     https://crypto.com/price/internet-computer
# UNUS SED LEO         LEO          https://crypto.com/price/unus-sed-leo
# ...

# %%
# if we want to specific columns

ipl.iloc[50:100,[2,4,9]]
# Out:
#           Date  MatchNumber TossDecision
# 50  2022-04-14           24        field
# 51  2022-04-13           23        field
# 52  2022-04-12           22        field
# 53  2022-04-11           21        field
# 54  2022-04-10           20        field
# 55  2022-04-10           19        field
# 56  2022-04-09           18        field
# 57  2022-04-09           17        field
# 58  2022-04-08           16        field
# 59  2022-04-07           15        field
# 60  2022-04-06           14        field
# 61  2022-04-05           13        field
# 62  2022-04-04           12        field
# 63  2022-04-03           11        field
# 64  2022-04-02           10        field
# 65  2022-04-02            9        field
# 66  2022-04-01            8        field
# 67  2022-03-31            7        field
# 68  2022-03-30            6        field
# 69  2022-03-29            5        field
# 70  2022-03-28            4        field
# 71  2022-03-27            3        field
# ...

# %%
crypto.loc['Shiba Inu':'Uniswap',['marketcap','price']]
# Out:
#                      marketcap         price
# name
# Shiba Inu          3,74,571.88      0.000023
# Avalanche            67,466.80     35.560000
# TRON               5,90,096.17      0.126600
# Wrapped Bitcoin    3,30,871.61  62741.270000
# Polkadot           7,30,393.90      7.070000
# Bitcoin Cash       4,40,989.28    452.270000
# Chainlink          8,24,768.57     14.260000
# NEAR Protocol      6,49,709.66      7.430000
# Polygon            2,42,167.49      0.696800
# Litecoin           3,20,998.95     83.060000
# Internet Computer  8,98,738.14     12.320000
# UNUS SED LEO       4,72,780.68      5.890000
# Dai                7,06,209.85      0.999600
# Uniswap            7,91,777.79      7.480000

# %%
# find all the final winners

ipl.head()
ipl[ipl['MatchNumber']=='Final'][['Season','WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
#  how many super over finishes have occured

ipl[ipl['SuperOver']=='Y'].shape[0]
# Out:
# 14

# %%
# how many matches has csk won in kolkata

ipl[(ipl['City']=='Kolkata') & (ipl['WinningTeam']=='Chennai Super Kings')]
# Out:
#           ID     City        Date   Season MatchNumber                  Team1  \
# 224  1178404  Kolkata  2019-04-14     2019          29  Kolkata Knight Riders
# 602   598022  Kolkata  2013-04-20     2013          26  Kolkata Knight Riders
# 641   548368  Kolkata  2012-05-14     2012          63  Kolkata Knight Riders
# 827   419113  Kolkata  2010-03-16  2009/10           8  Kolkata Knight Riders
# 908   336025  Kolkata  2008-05-18  2007/08          41  Kolkata Knight Riders
#
#                    Team2         Venue             TossWinner TossDecision  \
# 224  Chennai Super Kings  Eden Gardens    Chennai Super Kings        field
# 602  Chennai Super Kings  Eden Gardens  Kolkata Knight Riders          bat
# 641  Chennai Super Kings  Eden Gardens    Chennai Super Kings        field
# 827  Chennai Super Kings  Eden Gardens    Chennai Super Kings          bat
# 908  Chennai Super Kings  Eden Gardens  Kolkata Knight Riders          bat
#
# ...
